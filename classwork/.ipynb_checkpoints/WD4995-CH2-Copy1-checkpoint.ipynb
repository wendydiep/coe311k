# %%
number = 2025
remainders = ""

while number > 0:
    remainder = number % 2
    remainders = str(remainder) + remainders
    number = number // 2

print("Binary =", remainders)
# Out:
# Binary = 11111101001
