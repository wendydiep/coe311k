# %% [markdown]
# Hello Python! This is my very first notebook.

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(5)
# Out:
# 5

# %%
print(5+1)
# Out:
# 6

# %%
name = "Charlie"
NAME = "ALEX"

# %%
print(name)
# Out:
# Charlie

# %%
print(NAME)
# Out:
# ALEX

# %%
num1=5

# %%
num2= 7.5

# %%
a="Hello"
b= True

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# bool

# %%
type(num2)
# Out:
# int

# %%
type(num1)
# Out:
# int

# %%
string1 = str(num2)

# %%
print(string1)
print(type(string1))
# Out:
# 7
# <class 'str'>

# %%
num4 = 2**3

# %%
number1 = 5.0/2
number2 = 5/2
print (number1)
print (number2)
# Out:
# 2.5
# 2.5

# %%
numIn = input("Enter a number:")
# Out:
# Enter a number:5

# %%
print(type(num1))
# Out:
# <class 'int'>

# %%
myfile = open("test.data",'w')
myfile.write(numIn)
myfile.write("\n")
myfile.write("Hello World\n")
myfile.close()

# %%
myfile2 = open("test.data", 'r')
content = myfile2.read()
myfile2.close()
print(content)
# Out:
# 5
# Hello World

# %%
a = 2
b = 3

# %%
print(a>b)
# Out:
# False

# %%
print (b>a)
# Out:
# True

# %%
print(b!=a)
# Out:
# True

# %%
print (b!=a and a<b)
# Out:
# True

# %%
if(a>b):print("A is greater than B")

# %%
if(a<b):print("A is less than B")
# Out:
# A is less than B

# %%
if (b>a):
    print("B is greater than A")
    print ("Conditionals are awesome!")
print ("All done!")
# Out:
# B is greater than A
# Conditionals are awesome!
# All done!

# %%
for r in range (1,3):
    print (r,r**2)
# Out:
# 1 1
# 2 4

# %%
for i in range(1,4):
    for j in range (2,7):
        print (i,j)
# Out:
# 1 2
# 1 3
# 1 4
# 1 5
# 1 6
# 2 2
# 2 3
# 2 4
# 2 5
# 2 6
# 3 2
# 3 3
# 3 4
# 3 5
# 3 6

# %%
mylist = ["Wendy", 10, "Green", 42, "Alex", 9, "Black", 21]

# %%
for t in mylist:
    print(t)
# Out:
# Wendy
# 10
# Green
# 42
# Alex
# 9
# Black
# 21

# %%
for t in mylist:
    print(t, type(t))
# Out:
# Wendy <class 'str'>
# 10 <class 'int'>
# Green <class 'str'>
# 42 <class 'int'>
# Alex <class 'str'>
# 9 <class 'int'>
# Black <class 'str'>
# 21 <class 'int'>

# %%
print(mylist[0:3])
# Out:
# ['Wendy', 10, 'Green']

# %%
print(mylist[:3])
# Out:
# ['Wendy', 10, 'Green']

# %%
print ("Wendy" in mylist)
# Out:
# True

# %%
import math

def calc_hyp(a,b):
    h = math.sqrt(a*a + b*b)
    return h

# %%
my_h = calc_hyp(3, 4)
print(my_h)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-afd0bc9b544c> in <module>
# ----> 1 my_h = calc_hyp(3, 4)
#       2 print(my_h)
#
# <ipython-input-56-d90f4099a283> in calc_hyp(a, b)
#       2
#       3 def calc_hyp(a,b):
# ----> 4     h = sqrt(a*a + b*b)
#       5     return h
#
# NameError: name 'sqrt' is not defined

# %%
import random

for i in range(0,50):
    value = random.uniform(-1,1)
    print (value)
# Out:
# 0.7362754351451246
# 0.5873169281301269
# 0.3478175393144136
# -0.17241477344117961
# -0.10651713128025642
# -0.7154156493138966
# -0.023711165278561763
# 0.30756979006428486
# -0.9824412132395426
# 0.10072507096823013
# 0.7226066485927618
# -0.5762450601607971
# 0.23254259912438413
# 0.4372700831403711
# -0.8880581288380298
# 0.1763848345703367
# 0.574451302276604
# 0.0030487764455255917
# -0.9047940211265526
# 0.3742934135565139
# 0.9660969664582195
# -0.0826704751710643
# -0.7330797218230891
# -0.8001773680737059
# -0.8764827357967273
# 0.6710078690885106
# -0.5143394779190076
# 0.6378972167402861
# -0.6339131417786925
# 0.06401321821357664
# -0.23934677094558565
# 0.8878626232454683
# 0.4048173425954247
# 0.14775686519414588
# -0.1408520406444116
# -0.08657878247260853
# -0.6904618750087987
# 0.6105945258918408
# 0.9289901377439773
# 0.3235642634751721
# -0.7713673260309719
# 0.8480215850665429
# -0.5270534973163341
# 0.20572661034521067
# -0.4869833703071995
# -0.20530915961823748
# -0.6537427849585538
# -0.732396494299308
# -0.6034992976967111
# 0.4647522440127614

# %%
import random

def montecarlo_pi(number_of_shots):
    number_of_hits = 0
    for i in range(0,number_of_shots):
        x=random.uniform(-1,1)
        y=random.uniform(-1,1)
        
        if (x*x + y*y < 1):
            number_of_hits = number_of_hits +1
             
    return 4*number_of_hits/number_of_shots

# %%
montecarlo_pi(100000)
# Out:
# 3.13844
